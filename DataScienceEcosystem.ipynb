# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notebook demonstrates the use of Jupyter Notebooks for both documentation and computation. It shows how to create and format text using Markdown cells, including headings, lists, and tables, as well as how to execute Python code cells for simple arithmetic and unit conversions. The notebook highlights essential tools and practices that form the foundation of data science workflows.

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - Introduce common libraries used in Data Science
# - Demonstrate basic arithmetic in Python

# %% [markdown]
# | Language | Description |
# |----------|-------------|
# | Python   | Widely used for data analysis and machine learning |
# | R        | Popular for statistical computing and graphics |
# | SQL      | Used for managing and querying relational databases |

# %% [markdown]
# | Library    | Purpose                          |
# |------------|----------------------------------|
# | Pandas     | Data manipulation and analysis   |
# | NumPy      | Numerical computing               |
# | Matplotlib | Data visualization               |

# %% [markdown]
# **Common Development Tools:**
# - Jupyter Notebook
# - RStudio
# - Visual Studio Code

# %%
# This is a simple arithmetic operation
3 * 4 + 5
# Out:
# 17

# %%
minutes = 200
hours = minutes / 60.0
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# **Author:** Jehosaphat Brobbey Impiani

# %% [markdown]
# **Summary**
#
# This notebook demonstrated how to use Jupyter Notebooks for both documentation and computation. It showed how to format text with Markdown cells (including headings, lists, and tables), how to record objectives and author details, and how to execute Python code for simple tasks such as arithmetic operations and unit conversions. Together, these exercises highlight the essential skills needed to combine narrative and code in a single, reproducible workflow.
